# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\user\Desktop\Python-Projects-master\Machiine Learning\10FeatureScaling-Standarization\Social_Network_Ads.csv")
df.sample(5)
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 338  15810800  Female   38            55000          0
# 105  15801658    Male   21            72000          0
# 287  15761950  Female   48           138000          1
# 295  15725794  Female   36            63000          0
# 148  15779862    Male   29            61000          0

# %%
df.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
df.shape
# Out:
# (400, 5)

# %%
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
sns.distplot(df["EstimatedSalary"])
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22324\2569485762.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["EstimatedSalary"])

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
ss.fit(df[["EstimatedSalary"]])
# Out:
# StandardScaler()

# %%
df["EstimatedSalary_ss"] = pd.DataFrame(ss.transform(df[["EstimatedSalary"]]) ,columns=["x"])

# %%
df.head(3)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased  EstimatedSalary_ss
# 0  15624510    Male   19            19000          0           -1.490046
# 1  15810944    Male   35            20000          0           -1.460681
# 2  15668575  Female   26            43000          0           -0.785290

# %%
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased  \
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000
#
#        EstimatedSalary_ss
# count        4.000000e+02
# mean        -1.776357e-17
# std          1.001252e+00
# min         -1.607506e+00
# 25%         -7.852897e-01
# 50%          7.561451e-03
# 75%          5.361289e-01
# max          2.356750e+00

# %%
sns.distplot(df["EstimatedSalary_ss"])
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22324\721295579.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["EstimatedSalary_ss"])

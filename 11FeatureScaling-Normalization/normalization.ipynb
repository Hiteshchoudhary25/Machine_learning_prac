# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\user\Desktop\Python-Projects-master\Machiine Learning\11FeatureScaling-Normalization\wine_data.csv" ,header=None,usecols=[0,1,2])
df.columns=['Class label', 'Alcohol', 'Malic acid']
df.head(3)
# Out:
#    Class label  Alcohol  Malic acid
# 0            1    14.23        1.71
# 1            1    13.20        1.78
# 2            1    13.16        2.36

# %%
df.describe()
# Out:
#        Class label     Alcohol  Malic acid
# count   178.000000  178.000000  178.000000
# mean      1.938202   13.000618    2.336348
# std       0.775035    0.811827    1.117146
# min       1.000000   11.030000    0.740000
# 25%       1.000000   12.362500    1.602500
# 50%       2.000000   13.050000    1.865000
# 75%       3.000000   13.677500    3.082500
# max       3.000000   14.830000    5.800000

# %%
df.isnull().sum()
# Out:
# Class label    0
# Alcohol        0
# Malic acid     0
# dtype: int64

# %%
sns.distplot(df["Malic acid"])
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19836\140633351.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Malic acid"])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
ms = MinMaxScaler()
ms.fit(df[["Malic acid"]])
# Out:
# MinMaxScaler()

# %%
df["Malic acid_min"] = ms.transform(df[["Malic acid"]])

# %%
df.head(3)
# Out:
#    Class label  Alcohol  Malic acid  Malic acid_min
# 0            1    14.23        1.71        0.191700
# 1            1    13.20        1.78        0.205534
# 2            1    13.16        2.36        0.320158

# %%
df.describe()
# Out:
#        Class label     Alcohol  Malic acid  Malic acid_min
# count   178.000000  178.000000  178.000000      178.000000
# mean      1.938202   13.000618    2.336348        0.315484
# std       0.775035    0.811827    1.117146        0.220780
# min       1.000000   11.030000    0.740000        0.000000
# 25%       1.000000   12.362500    1.602500        0.170455
# 50%       2.000000   13.050000    1.865000        0.222332
# 75%       3.000000   13.677500    3.082500        0.462945
# max       3.000000   14.830000    5.800000        1.000000

# %%
sns.distplot(df["Malic acid_min"])
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19836\1462653634.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Malic acid_min"])

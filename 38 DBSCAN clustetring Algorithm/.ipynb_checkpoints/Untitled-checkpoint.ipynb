# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_moons
import pandas as pd

# %%
x,y = make_moons(n_samples=250,noise=0.05)

# %%
df = {"data1" : x[ : , 0] , "data2" : x[ : , 1] }

# %%
dataset = pd.DataFrame(df)

# %%
dataset
# Out:
#         data1     data2
# 0    0.902648  0.508512
# 1   -0.394201  0.913408
# 2    0.698944  0.673024
# 3    1.961150  0.343932
# 4   -0.299197  1.013771
# ..        ...       ...
# 245  0.116291 -0.061707
# 246  0.302620 -0.159485
# 247 -0.997160  0.274978
# 248  0.569586  0.863439
# 249  0.527270 -0.369999
#
# [250 rows x 2 columns]

# %%
sns.scatterplot(x="data1" , y="data2"  , data=dataset)
plt.show()

# %%
from sklearn.cluster import DBSCAN

# %%
db = DBSCAN(eps=0.3 ,min_samples=5)
dataset["predict"] = db.fit_predict(dataset)

# %%
dataset
# Out:
#         data1     data2  predict
# 0    0.902648  0.508512        0
# 1   -0.394201  0.913408        0
# 2    0.698944  0.673024        0
# 3    1.961150  0.343932        1
# 4   -0.299197  1.013771        0
# ..        ...       ...      ...
# 245  0.116291 -0.061707        1
# 246  0.302620 -0.159485        1
# 247 -0.997160  0.274978        0
# 248  0.569586  0.863439        0
# 249  0.527270 -0.369999        1
#
# [250 rows x 3 columns]

# %%
sns.scatterplot(x="data1" , y="data2" , hue="predict" , data=dataset)
plt.show()
